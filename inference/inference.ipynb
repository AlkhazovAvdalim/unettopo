# %%
import pathlib
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
import keras.layers as layers
from pathlib import Path
import matplotlib.pyplot as plt
import os
from tqdm import tqdm_notebook
import nbimporter
import data_modification_inf as Modify
import split_data_inf as Split
import create_output_txt as Outtxt
import subprocess
from shutil import copyfile
import time

import keras.backend as K
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
def kullback_leibler_divergence_test_2(y_true, y_pred):

    y_true = K.clip(y_true, K.epsilon(), 1)
    y_pred = K.clip(y_pred, K.epsilon(), 1)
    return K.sum(y_true * abs(K.log(y_true /  y_pred)), axis=-1)

custom_metr = custom_objects={
        "kullback_leibler_divergence_test_2":kullback_leibler_divergence_test_2,
        "dice_coef": dice_coef}
def load_model(ID, MODEL_ROOT):
    model_path  =os.path.join(MODEL_ROOT,str(ID+".h5"))
    loaded_model = tf.keras.models.load_model(model_path,custom_metr)
    return loaded_model
# Out:
# C:\Users\Avdalim\Anaconda3\envs\Thesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Avdalim\Anaconda3\envs\Thesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Avdalim\Anaconda3\envs\Thesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Avdalim\Anaconda3\envs\Thesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Avdalim\Anaconda3\envs\Thesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Avdalim\Anaconda3\envs\Thesis\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# Importing Jupyter notebook from data_modification_inf.ipynb
# Importing Jupyter notebook from split_data_inf.ipynb
# Importing Jupyter notebook from create_output_txt.ipynb

# %%
DATA_PATH = "F:/Thesis/inference_folder/data/"
DATA_PATH_RAW = os.path.join(DATA_PATH,"raw")
TEMP_PATH = "F:/Thesis/inference_folder/temp/"
os.makedirs(TEMP_PATH,exist_ok=True)
MODEL_PATH = "F:/Thesis/inference_folder/utils/"
model_ID = "ID_317"
SAVE_ROOT = "F:/Thesis/inference_folder/out/"
os.makedirs(TEMP_PATH,exist_ok=True)
MODIFIED_DATA_PATH = os.path.join(TEMP_PATH,"modified")
os.makedirs(MODIFIED_DATA_PATH,exist_ok=True)
SPLIT_DATA_PATH = os.path.join(TEMP_PATH,"split")
os.makedirs(SPLIT_DATA_PATH,exist_ok=True)
CONVERTER_PATH = "F:/Thesis/inference_folder/utils/"
SPEC_SAVE_ROOT = os.path.join(SAVE_ROOT, model_ID)

# %%
Modify.full_auto(DATA_PATH, MODIFIED_DATA_PATH)
# Out:
# F:\Thesis\inference_folder\data\raw
# 0
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
Split.full_auto_split(MODIFIED_DATA_PATH,SPLIT_DATA_PATH)
# Out:
# ['F:\\Thesis\\inference_folder\\temp\\modified\\raw'] ['F:/Thesis/inference_folder/temp/split\\raw']
# F:\Thesis\inference_folder\temp\modified\raw ['checkpoint.npy' 'faulty.npy' 'LoadCase_7813.npy' 'LoadCase_7814.npy'
#  'LoadCase_7815.npy' 'LoadCase_7816.npy' 'LoadCase_7817.npy'
#  'LoadCase_7818.npy' 'LoadCase_7819.npy' 'LoadCase_7820.npy'
#  'LoadCase_7821.npy' 'LoadCase_7822.npy' 'LoadCase_7823.npy'
#  'LoadCase_7824.npy' 'LoadCase_7825.npy' 'LoadCase_7826.npy'
#  'LoadCase_7827.npy' 'LoadCase_7828.npy' 'LoadCase_7829.npy'
#  'LoadCase_7830.npy' 'LoadCase_7831.npy' 'LoadCase_7832.npy'
#  'LoadCase_7833.npy' 'LoadCase_7834.npy' 'LoadCase_7835.npy'
#  'LoadCase_7836.npy' 'LoadCase_7837.npy' 'LoadCase_7838.npy'
#  'LoadCase_7839.npy' 'LoadCase_7840.npy' 'LoadCase_7842.npy'
#  'LoadCase_7843.npy' 'LoadCase_7844.npy' 'LoadCase_7845.npy'
#  'LoadCase_7846.npy' 'LoadCase_7847.npy' 'LoadCase_7848.npy'
#  'LoadCase_7849.npy' 'LoadCase_7850.npy' 'LoadCase_7851.npy'
#  'LoadCase_7852.npy' 'LoadCase_7853.npy' 'LoadCase_7854.npy'
#  'LoadCase_7855.npy' 'LoadCase_7856.npy' 'LoadCase_7857.npy'
#  'LoadCase_7858.npy' 'LoadCase_7859.npy' 'LoadCase_7860.npy'
#  'LoadCase_7861.npy' 'LoadCase_7862.npy' 'LoadCase_7863.npy'
#  'LoadCase_7864.npy' 'LoadCase_7865.npy' 'LoadCase_7866.npy'
#  'LoadCase_7867.npy' 'LoadCase_7868.npy' 'LoadCase_7869.npy'
#  'LoadCase_7870.npy' 'LoadCase_7871.npy' 'LoadCase_7872.npy'
#  'LoadCase_7873.npy' 'LoadCase_7874.npy' 'LoadCase_7875.npy'
#  'LoadCase_7876.npy' 'LoadCase_7877.npy' 'LoadCase_7878.npy'
#  'LoadCase_7879.npy' 'LoadCase_7880.npy' 'LoadCase_7881.npy'
#  'LoadCase_7882.npy' 'LoadCase_7883.npy' 'LoadCase_7884.npy'
#  'LoadCase_7885.npy' 'LoadCase_7886.npy' 'LoadCase_7887.npy'
#  'LoadCase_7888.npy' 'LoadCase_7889.npy' 'LoadCase_7890.npy'
#  'LoadCase_7891.npy' 'LoadCase_7892.npy' 'LoadCase_7893.npy'
#  'LoadCase_7894.npy' 'LoadCase_7895.npy' 'LoadCase_7896.npy'
#  'LoadCase_7897.npy' 'LoadCase_7898.npy' 'LoadCase_7899.npy'
#  'LoadCase_7900.npy' 'LoadCase_7901.npy' 'LoadCase_7902.npy'
#  'LoadCase_7903.npy' 'LoadCase_7904.npy' 'LoadCase_7905.npy'
#  'LoadCase_7906.npy' 'LoadCase_7907.npy' 'LoadCase_7908.npy'
#  'LoadCase_7909.npy' 'LoadCase_7910.npy' 'LoadCase_7911.npy'
#  'LoadCase_7912.npy' 'LoadCase_7913.npy' 'LoadCase_7914.npy'
#  'LoadCase_7915.npy' 'LoadCase_7916.npy' 'LoadCase_7917.npy'
#  'LoadCase_7918.npy' 'LoadCase_7919.npy' 'LoadCase_7920.npy'
#  'LoadCase_7921.npy' 'LoadCase_7922.npy' 'LoadCase_7923.npy'
#  'LoadCase_7924.npy' 'LoadCase_7925.npy' 'LoadCase_7926.npy'
#  'LoadCase_7927.npy' 'LoadCase_7928.npy' 'LoadCase_7929.npy'
#  'LoadCase_7930.npy' 'LoadCase_7931.npy' 'LoadCase_7932.npy'
#  'LoadCase_7933.npy' 'LoadCase_7934.npy' 'LoadCase_7935.npy'
#  'LoadCase_7936.npy' 'LoadCase_7937.npy' 'LoadCase_7938.npy'
#  'LoadCase_7939.npy' 'LoadCase_7940.npy' 'LoadCase_7941.npy'
#  'LoadCase_7942.npy' 'LoadCase_7943.npy' 'LoadCase_7944.npy'
#  'LoadCase_7945.npy' 'LoadCase_7946.npy' 'LoadCase_7947.npy'
#  'LoadCase_7948.npy' 'LoadCase_7949.npy' 'LoadCase_7950.npy'
#  'LoadCase_7951.npy' 'LoadCase_7952.npy' 'LoadCase_7953.npy'
#  'LoadCase_7954.npy' 'LoadCase_7955.npy' 'LoadCase_7956.npy'
#  'LoadCase_7957.npy' 'LoadCase_7958.npy' 'LoadCase_7959.npy'
#  'LoadCase_7960.npy' 'LoadCase_7961.npy' 'LoadCase_7962.npy'
#  'LoadCase_7963.npy' 'LoadCase_7964.npy' 'LoadCase_7965.npy'
#  'LoadCase_7966.npy' 'LoadCase_7967.npy' 'LoadCase_7968.npy'
#  'LoadCase_7970.npy' 'LoadCase_7971.npy' 'LoadCase_7972.npy'
#  'LoadCase_7973.npy' 'LoadCase_7974.npy' 'LoadCase_7975.npy'
#  'LoadCase_7976.npy' 'LoadCase_7977.npy' 'LoadCase_7978.npy'
#  'LoadCase_7979.npy' 'LoadCase_7980.npy' 'LoadCase_7981.npy'
#  'LoadCase_7982.npy' 'LoadCase_7983.npy' 'LoadCase_7984.npy'
#  'LoadCase_7985.npy' 'LoadCase_7986.npy' 'LoadCase_7987.npy'
#  'LoadCase_7988.npy' 'LoadCase_7989.npy' 'LoadCase_7990.npy'
#  'LoadCase_7991.npy' 'LoadCase_7992.npy' 'LoadCase_7993.npy'
#  'LoadCase_7994.npy' 'LoadCase_7995.npy' 'LoadCase_7996.npy'
#  'LoadCase_7997.npy' 'LoadCase_7998.npy' 'LoadCase_7999.npy'] F:/Thesis/inference_folder/temp/split\raw
# Checkpoint and Faulty found, skipping them, starting at:  ['LoadCase_7813.npy' 'LoadCase_7814.npy' 'LoadCase_7815.npy'
#  'LoadCase_7816.npy' 'LoadCase_7817.npy' 'LoadCase_7818.npy'
#  'LoadCase_7819.npy' 'LoadCase_7820.npy' 'LoadCase_7821.npy'
#  'LoadCase_7822.npy' 'LoadCase_7823.npy' 'LoadCase_7824.npy'
#  'LoadCase_7825.npy' 'LoadCase_7826.npy' 'LoadCase_7827.npy'
#  'LoadCase_7828.npy' 'LoadCase_7829.npy' 'LoadCase_7830.npy'
#  'LoadCase_7831.npy' 'LoadCase_7832.npy' 'LoadCase_7833.npy'
#  'LoadCase_7834.npy' 'LoadCase_7835.npy' 'LoadCase_7836.npy'
#  'LoadCase_7837.npy' 'LoadCase_7838.npy' 'LoadCase_7839.npy'
#  'LoadCase_7840.npy' 'LoadCase_7842.npy' 'LoadCase_7843.npy'
#  'LoadCase_7844.npy' 'LoadCase_7845.npy' 'LoadCase_7846.npy'
#  'LoadCase_7847.npy' 'LoadCase_7848.npy' 'LoadCase_7849.npy'
#  'LoadCase_7850.npy' 'LoadCase_7851.npy' 'LoadCase_7852.npy'
#  'LoadCase_7853.npy' 'LoadCase_7854.npy' 'LoadCase_7855.npy'
#  'LoadCase_7856.npy' 'LoadCase_7857.npy' 'LoadCase_7858.npy'
#  'LoadCase_7859.npy' 'LoadCase_7860.npy' 'LoadCase_7861.npy'
#  'LoadCase_7862.npy' 'LoadCase_7863.npy' 'LoadCase_7864.npy'
#  'LoadCase_7865.npy' 'LoadCase_7866.npy' 'LoadCase_7867.npy'
#  'LoadCase_7868.npy' 'LoadCase_7869.npy' 'LoadCase_7870.npy'
#  'LoadCase_7871.npy' 'LoadCase_7872.npy' 'LoadCase_7873.npy'
#  'LoadCase_7874.npy' 'LoadCase_7875.npy' 'LoadCase_7876.npy'
#  'LoadCase_7877.npy' 'LoadCase_7878.npy' 'LoadCase_7879.npy'
#  'LoadCase_7880.npy' 'LoadCase_7881.npy' 'LoadCase_7882.npy'
#  'LoadCase_7883.npy' 'LoadCase_7884.npy' 'LoadCase_7885.npy'
#  'LoadCase_7886.npy' 'LoadCase_7887.npy' 'LoadCase_7888.npy'
#  'LoadCase_7889.npy' 'LoadCase_7890.npy' 'LoadCase_7891.npy'
#  'LoadCase_7892.npy' 'LoadCase_7893.npy' 'LoadCase_7894.npy'
#  'LoadCase_7895.npy' 'LoadCase_7896.npy' 'LoadCase_7897.npy'
#  'LoadCase_7898.npy' 'LoadCase_7899.npy' 'LoadCase_7900.npy'
#  'LoadCase_7901.npy' 'LoadCase_7902.npy' 'LoadCase_7903.npy'
#  'LoadCase_7904.npy' 'LoadCase_7905.npy' 'LoadCase_7906.npy'
#  'LoadCase_7907.npy' 'LoadCase_7908.npy' 'LoadCase_7909.npy'
#  'LoadCase_7910.npy' 'LoadCase_7911.npy' 'LoadCase_7912.npy'
#  'LoadCase_7913.npy' 'LoadCase_7914.npy' 'LoadCase_7915.npy'
#  'LoadCase_7916.npy' 'LoadCase_7917.npy' 'LoadCase_7918.npy'
#  'LoadCase_7919.npy' 'LoadCase_7920.npy' 'LoadCase_7921.npy'
#  'LoadCase_7922.npy' 'LoadCase_7923.npy' 'LoadCase_7924.npy'
#  'LoadCase_7925.npy' 'LoadCase_7926.npy' 'LoadCase_7927.npy'
#  'LoadCase_7928.npy' 'LoadCase_7929.npy' 'LoadCase_7930.npy'
#  'LoadCase_7931.npy' 'LoadCase_7932.npy' 'LoadCase_7933.npy'
#  'LoadCase_7934.npy' 'LoadCase_7935.npy' 'LoadCase_7936.npy'
#  'LoadCase_7937.npy' 'LoadCase_7938.npy' 'LoadCase_7939.npy'
#  'LoadCase_7940.npy' 'LoadCase_7941.npy' 'LoadCase_7942.npy'
#  'LoadCase_7943.npy' 'LoadCase_7944.npy' 'LoadCase_7945.npy'
#  'LoadCase_7946.npy' 'LoadCase_7947.npy' 'LoadCase_7948.npy'
#  'LoadCase_7949.npy' 'LoadCase_7950.npy' 'LoadCase_7951.npy'
#  'LoadCase_7952.npy' 'LoadCase_7953.npy' 'LoadCase_7954.npy'
#  'LoadCase_7955.npy' 'LoadCase_7956.npy' 'LoadCase_7957.npy'
#  'LoadCase_7958.npy' 'LoadCase_7959.npy' 'LoadCase_7960.npy'
#  'LoadCase_7961.npy' 'LoadCase_7962.npy' 'LoadCase_7963.npy'
#  'LoadCase_7964.npy' 'LoadCase_7965.npy' 'LoadCase_7966.npy'
#  'LoadCase_7967.npy' 'LoadCase_7968.npy' 'LoadCase_7970.npy'
#  'LoadCase_7971.npy' 'LoadCase_7972.npy' 'LoadCase_7973.npy'
#  'LoadCase_7974.npy' 'LoadCase_7975.npy' 'LoadCase_7976.npy'
#  'LoadCase_7977.npy' 'LoadCase_7978.npy' 'LoadCase_7979.npy'
#  'LoadCase_7980.npy' 'LoadCase_7981.npy' 'LoadCase_7982.npy'
#  'LoadCase_7983.npy' 'LoadCase_7984.npy' 'LoadCase_7985.npy'
#  'LoadCase_7986.npy' 'LoadCase_7987.npy' 'LoadCase_7988.npy'
#  'LoadCase_7989.npy' 'LoadCase_7990.npy' 'LoadCase_7991.npy'
#  'LoadCase_7992.npy' 'LoadCase_7993.npy' 'LoadCase_7994.npy'
#  'LoadCase_7995.npy' 'LoadCase_7996.npy' 'LoadCase_7997.npy'
#  'LoadCase_7998.npy' 'LoadCase_7999.npy']
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
tf.keras.backend.clear_session()
model = load_model(model_ID,MODEL_PATH)

# %%
MODIFIED_DATA_PATH_temp, SPLIT_DATA_PATH_temp = Modify.loadcase_folder_paths(MODIFIED_DATA_PATH,SPLIT_DATA_PATH)

for i , s in enumerate(SPLIT_DATA_PATH_temp):
    print(s)
    Outtxt.create_prediction_txt(model,DATA_PATH_RAW,s, model_ID
                          ,SPEC_SAVE_ROOT,CONVERTER_PATH)
# Out:
# F:/Thesis/inference_folder/temp/split\raw
# LoadCase_7813
# F:/Thesis/inference_folder/data/raw\LoadCase_7813
# Elapsed prediction time:  0.5566482543945312
# LoadCase_7814
# F:/Thesis/inference_folder/data/raw\LoadCase_7814
# Elapsed prediction time:  0.07420563697814941
# LoadCase_7815
# F:/Thesis/inference_folder/data/raw\LoadCase_7815
# Elapsed prediction time:  0.07178640365600586
# LoadCase_7816
# F:/Thesis/inference_folder/data/raw\LoadCase_7816
# Elapsed prediction time:  0.07380247116088867
# LoadCase_7817
# F:/Thesis/inference_folder/data/raw\LoadCase_7817
# Elapsed prediction time:  0.07420778274536133
# LoadCase_7818
# F:/Thesis/inference_folder/data/raw\LoadCase_7818
# Elapsed prediction time:  0.07274913787841797
# LoadCase_7819
# F:/Thesis/inference_folder/data/raw\LoadCase_7819
# Elapsed prediction time:  0.07280564308166504
# LoadCase_7820
# F:/Thesis/inference_folder/data/raw\LoadCase_7820
# Elapsed prediction time:  0.07679414749145508
# LoadCase_7821
# F:/Thesis/inference_folder/data/raw\LoadCase_7821
# Elapsed prediction time:  0.07280540466308594
# LoadCase_7822
# F:/Thesis/inference_folder/data/raw\LoadCase_7822
# Elapsed prediction time:  0.07485532760620117
# LoadCase_7823
# F:/Thesis/inference_folder/data/raw\LoadCase_7823
# Elapsed prediction time:  0.07380294799804688
# LoadCase_7824
# F:/Thesis/inference_folder/data/raw\LoadCase_7824
# Elapsed prediction time:  0.07574129104614258
# LoadCase_7825
# F:/Thesis/inference_folder/data/raw\LoadCase_7825
# Elapsed prediction time:  0.07184672355651855
# LoadCase_7826
# F:/Thesis/inference_folder/data/raw\LoadCase_7826
# Elapsed prediction time:  0.07782506942749023
# LoadCase_7827
# F:/Thesis/inference_folder/data/raw\LoadCase_7827
# Elapsed prediction time:  0.08776473999023438
# LoadCase_7828
# F:/Thesis/inference_folder/data/raw\LoadCase_7828
# Elapsed prediction time:  0.07274603843688965
# LoadCase_7829
# F:/Thesis/inference_folder/data/raw\LoadCase_7829
# Elapsed prediction time:  0.07675695419311523
# LoadCase_7830
# F:/Thesis/inference_folder/data/raw\LoadCase_7830
# Elapsed prediction time:  0.07779288291931152
# LoadCase_7831
# F:/Thesis/inference_folder/data/raw\LoadCase_7831
# Elapsed prediction time:  0.08078432083129883
# LoadCase_7832
# F:/Thesis/inference_folder/data/raw\LoadCase_7832
# Elapsed prediction time:  0.08676981925964355
# LoadCase_7833
# F:/Thesis/inference_folder/data/raw\LoadCase_7833
# Elapsed prediction time:  0.0727691650390625
# LoadCase_7834
# F:/Thesis/inference_folder/data/raw\LoadCase_7834
# Elapsed prediction time:  0.08576798439025879
# LoadCase_7835
# F:/Thesis/inference_folder/data/raw\LoadCase_7835
# Elapsed prediction time:  0.08377504348754883
# LoadCase_7836
# F:/Thesis/inference_folder/data/raw\LoadCase_7836
# Elapsed prediction time:  0.07523155212402344
# LoadCase_7837
# F:/Thesis/inference_folder/data/raw\LoadCase_7837
# Elapsed prediction time:  0.07280492782592773
# LoadCase_7838
# F:/Thesis/inference_folder/data/raw\LoadCase_7838
# Elapsed prediction time:  0.07579803466796875
# LoadCase_7839
# F:/Thesis/inference_folder/data/raw\LoadCase_7839
# Elapsed prediction time:  0.07376694679260254
# LoadCase_7840
# F:/Thesis/inference_folder/data/raw\LoadCase_7840
# Elapsed prediction time:  0.07283377647399902
# LoadCase_7842
# F:/Thesis/inference_folder/data/raw\LoadCase_7842
# Elapsed prediction time:  0.08178162574768066
# LoadCase_7843
# F:/Thesis/inference_folder/data/raw\LoadCase_7843
# Elapsed prediction time:  0.07470226287841797
# LoadCase_7844
# F:/Thesis/inference_folder/data/raw\LoadCase_7844
# Elapsed prediction time:  0.07978701591491699
# LoadCase_7845
# F:/Thesis/inference_folder/data/raw\LoadCase_7845
# Elapsed prediction time:  0.07579851150512695
# LoadCase_7846
# F:/Thesis/inference_folder/data/raw\LoadCase_7846
# Elapsed prediction time:  0.07380247116088867
# LoadCase_7847
# F:/Thesis/inference_folder/data/raw\LoadCase_7847
# Elapsed prediction time:  0.07579731941223145
# LoadCase_7848
# F:/Thesis/inference_folder/data/raw\LoadCase_7848
# Elapsed prediction time:  0.07546305656433105
# LoadCase_7849
# F:/Thesis/inference_folder/data/raw\LoadCase_7849
# Elapsed prediction time:  0.07480049133300781
# LoadCase_7850
# F:/Thesis/inference_folder/data/raw\LoadCase_7850
# Elapsed prediction time:  0.07380223274230957
# LoadCase_7851
# F:/Thesis/inference_folder/data/raw\LoadCase_7851
# Elapsed prediction time:  0.07279658317565918
# LoadCase_7852
# F:/Thesis/inference_folder/data/raw\LoadCase_7852
# Elapsed prediction time:  0.07579803466796875
# LoadCase_7853
# F:/Thesis/inference_folder/data/raw\LoadCase_7853
# Elapsed prediction time:  0.07380294799804688
# LoadCase_7854
# F:/Thesis/inference_folder/data/raw\LoadCase_7854
# Elapsed prediction time:  0.07852816581726074
# LoadCase_7855
# F:/Thesis/inference_folder/data/raw\LoadCase_7855
# Elapsed prediction time:  0.07384347915649414
# LoadCase_7856
# F:/Thesis/inference_folder/data/raw\LoadCase_7856
# Elapsed prediction time:  0.07380366325378418
# LoadCase_7857
# F:/Thesis/inference_folder/data/raw\LoadCase_7857
# Elapsed prediction time:  0.0767977237701416
# LoadCase_7858
# F:/Thesis/inference_folder/data/raw\LoadCase_7858
# Elapsed prediction time:  0.07284402847290039
# LoadCase_7859
# F:/Thesis/inference_folder/data/raw\LoadCase_7859
# Elapsed prediction time:  0.07579874992370605
# LoadCase_7860
# F:/Thesis/inference_folder/data/raw\LoadCase_7860
# Elapsed prediction time:  0.08377623558044434
# LoadCase_7861
# F:/Thesis/inference_folder/data/raw\LoadCase_7861
# Elapsed prediction time:  0.07573556900024414
# LoadCase_7862
# F:/Thesis/inference_folder/data/raw\LoadCase_7862
# Elapsed prediction time:  0.08377623558044434
# LoadCase_7863
# F:/Thesis/inference_folder/data/raw\LoadCase_7863
# Elapsed prediction time:  0.08278012275695801
# LoadCase_7864
# F:/Thesis/inference_folder/data/raw\LoadCase_7864
# Elapsed prediction time:  0.07579708099365234
# LoadCase_7865
# F:/Thesis/inference_folder/data/raw\LoadCase_7865
# Elapsed prediction time:  0.07380247116088867
# LoadCase_7866
# F:/Thesis/inference_folder/data/raw\LoadCase_7866
# Elapsed prediction time:  0.0752878189086914
# LoadCase_7867
# F:/Thesis/inference_folder/data/raw\LoadCase_7867
# Elapsed prediction time:  0.07579803466796875
# LoadCase_7868
# F:/Thesis/inference_folder/data/raw\LoadCase_7868
# Elapsed prediction time:  0.07380414009094238
# LoadCase_7869
# F:/Thesis/inference_folder/data/raw\LoadCase_7869
# Elapsed prediction time:  0.07280373573303223
# LoadCase_7870
# F:/Thesis/inference_folder/data/raw\LoadCase_7870
# Elapsed prediction time:  0.10970592498779297
# LoadCase_7871
# F:/Thesis/inference_folder/data/raw\LoadCase_7871
# Elapsed prediction time:  0.07480072975158691
# LoadCase_7872
# F:/Thesis/inference_folder/data/raw\LoadCase_7872
# Elapsed prediction time:  0.07380461692810059
# LoadCase_7873
# F:/Thesis/inference_folder/data/raw\LoadCase_7873
# Elapsed prediction time:  0.07395315170288086
# LoadCase_7874
# F:/Thesis/inference_folder/data/raw\LoadCase_7874
# Elapsed prediction time:  0.07679390907287598
# LoadCase_7875
# F:/Thesis/inference_folder/data/raw\LoadCase_7875
# Elapsed prediction time:  0.07380294799804688
# LoadCase_7876
# F:/Thesis/inference_folder/data/raw\LoadCase_7876
# Elapsed prediction time:  0.07284045219421387
# LoadCase_7877
# F:/Thesis/inference_folder/data/raw\LoadCase_7877
# Elapsed prediction time:  0.07579755783081055
# LoadCase_7878
# F:/Thesis/inference_folder/data/raw\LoadCase_7878
# Elapsed prediction time:  0.07380342483520508
# LoadCase_7879
# F:/Thesis/inference_folder/data/raw\LoadCase_7879
# Elapsed prediction time:  0.0747995376586914
# LoadCase_7880
# F:/Thesis/inference_folder/data/raw\LoadCase_7880
# Elapsed prediction time:  0.07282400131225586
# LoadCase_7881
# F:/Thesis/inference_folder/data/raw\LoadCase_7881
# Elapsed prediction time:  0.07283520698547363
# LoadCase_7882
# F:/Thesis/inference_folder/data/raw\LoadCase_7882
# Elapsed prediction time:  0.07579970359802246
# LoadCase_7883
# F:/Thesis/inference_folder/data/raw\LoadCase_7883
# Elapsed prediction time:  0.08278441429138184
# LoadCase_7884
# F:/Thesis/inference_folder/data/raw\LoadCase_7884
# Elapsed prediction time:  0.0738370418548584
# LoadCase_7885
# F:/Thesis/inference_folder/data/raw\LoadCase_7885
# Elapsed prediction time:  0.08676862716674805
# LoadCase_7886
# F:/Thesis/inference_folder/data/raw\LoadCase_7886
# Elapsed prediction time:  0.07280540466308594
# LoadCase_7887
# F:/Thesis/inference_folder/data/raw\LoadCase_7887
# Elapsed prediction time:  0.07579731941223145
# LoadCase_7888
# F:/Thesis/inference_folder/data/raw\LoadCase_7888
# Elapsed prediction time:  0.07482004165649414
# LoadCase_7889
# F:/Thesis/inference_folder/data/raw\LoadCase_7889
# Elapsed prediction time:  0.07579827308654785
# LoadCase_7890
# F:/Thesis/inference_folder/data/raw\LoadCase_7890
# Elapsed prediction time:  0.07480001449584961
# LoadCase_7891
# F:/Thesis/inference_folder/data/raw\LoadCase_7891
# Elapsed prediction time:  0.07873129844665527
# LoadCase_7892
# F:/Thesis/inference_folder/data/raw\LoadCase_7892
# Elapsed prediction time:  0.07254385948181152
# LoadCase_7893
# F:/Thesis/inference_folder/data/raw\LoadCase_7893
# Elapsed prediction time:  0.0747981071472168
# LoadCase_7894
# F:/Thesis/inference_folder/data/raw\LoadCase_7894
# Elapsed prediction time:  0.0738058090209961
# LoadCase_7895
# F:/Thesis/inference_folder/data/raw\LoadCase_7895
# Elapsed prediction time:  0.07280516624450684
# LoadCase_7896
# F:/Thesis/inference_folder/data/raw\LoadCase_7896
# Elapsed prediction time:  0.0746004581451416
# LoadCase_7897
# F:/Thesis/inference_folder/data/raw\LoadCase_7897
# Elapsed prediction time:  0.07480788230895996
# LoadCase_7898
# F:/Thesis/inference_folder/data/raw\LoadCase_7898
# Elapsed prediction time:  0.07431936264038086
# LoadCase_7899
# F:/Thesis/inference_folder/data/raw\LoadCase_7899
# Elapsed prediction time:  0.07480120658874512
# LoadCase_7900
# F:/Thesis/inference_folder/data/raw\LoadCase_7900
# Elapsed prediction time:  0.07380294799804688
# LoadCase_7901
# F:/Thesis/inference_folder/data/raw\LoadCase_7901
# Elapsed prediction time:  0.07878899574279785
# LoadCase_7902
# F:/Thesis/inference_folder/data/raw\LoadCase_7902
# Elapsed prediction time:  0.07380247116088867
# LoadCase_7903
# F:/Thesis/inference_folder/data/raw\LoadCase_7903
# Elapsed prediction time:  0.07280516624450684
# LoadCase_7904
# F:/Thesis/inference_folder/data/raw\LoadCase_7904
# Elapsed prediction time:  0.07280468940734863
# LoadCase_7905
# F:/Thesis/inference_folder/data/raw\LoadCase_7905
# Elapsed prediction time:  0.07516884803771973
# LoadCase_7906
# F:/Thesis/inference_folder/data/raw\LoadCase_7906
# Elapsed prediction time:  0.07278180122375488
# LoadCase_7907
# F:/Thesis/inference_folder/data/raw\LoadCase_7907
# Elapsed prediction time:  0.07579755783081055
# LoadCase_7908
# F:/Thesis/inference_folder/data/raw\LoadCase_7908
# Elapsed prediction time:  0.07579922676086426
# LoadCase_7909
# F:/Thesis/inference_folder/data/raw\LoadCase_7909
# Elapsed prediction time:  0.07480096817016602
# LoadCase_7910
# F:/Thesis/inference_folder/data/raw\LoadCase_7910
# Elapsed prediction time:  0.07380342483520508
# LoadCase_7911
# F:/Thesis/inference_folder/data/raw\LoadCase_7911
# Elapsed prediction time:  0.07480096817016602
# LoadCase_7912
# F:/Thesis/inference_folder/data/raw\LoadCase_7912
# Elapsed prediction time:  0.0763845443725586
# LoadCase_7913
# F:/Thesis/inference_folder/data/raw\LoadCase_7913
# Elapsed prediction time:  0.08272147178649902
# LoadCase_7914
# F:/Thesis/inference_folder/data/raw\LoadCase_7914
# Elapsed prediction time:  0.07480144500732422
# LoadCase_7915
# F:/Thesis/inference_folder/data/raw\LoadCase_7915
# Elapsed prediction time:  0.08041024208068848
# LoadCase_7916
# F:/Thesis/inference_folder/data/raw\LoadCase_7916
# Elapsed prediction time:  0.07380080223083496
# LoadCase_7917
# F:/Thesis/inference_folder/data/raw\LoadCase_7917
# Elapsed prediction time:  0.07384300231933594
# LoadCase_7918
# F:/Thesis/inference_folder/data/raw\LoadCase_7918
# Elapsed prediction time:  0.08078432083129883
# LoadCase_7919
# F:/Thesis/inference_folder/data/raw\LoadCase_7919
# Elapsed prediction time:  0.07474064826965332
# LoadCase_7920
# F:/Thesis/inference_folder/data/raw\LoadCase_7920
# Elapsed prediction time:  0.07384228706359863
# LoadCase_7921
# F:/Thesis/inference_folder/data/raw\LoadCase_7921
# Elapsed prediction time:  0.07480025291442871
# LoadCase_7922
# F:/Thesis/inference_folder/data/raw\LoadCase_7922
# Elapsed prediction time:  0.07779192924499512
# LoadCase_7923
# F:/Thesis/inference_folder/data/raw\LoadCase_7923
# Elapsed prediction time:  0.0718083381652832
# LoadCase_7924
# F:/Thesis/inference_folder/data/raw\LoadCase_7924
# Elapsed prediction time:  0.08377408981323242
# LoadCase_7925
# F:/Thesis/inference_folder/data/raw\LoadCase_7925
# Elapsed prediction time:  0.07280611991882324
# LoadCase_7926
# F:/Thesis/inference_folder/data/raw\LoadCase_7926
# Elapsed prediction time:  0.07791852951049805
# LoadCase_7927
# F:/Thesis/inference_folder/data/raw\LoadCase_7927
# Elapsed prediction time:  0.07280564308166504
# LoadCase_7928
# F:/Thesis/inference_folder/data/raw\LoadCase_7928
# Elapsed prediction time:  0.07576274871826172
# LoadCase_7929
# F:/Thesis/inference_folder/data/raw\LoadCase_7929
# Elapsed prediction time:  0.07938218116760254
# LoadCase_7930
# F:/Thesis/inference_folder/data/raw\LoadCase_7930
# Elapsed prediction time:  0.07380461692810059
# LoadCase_7931
# F:/Thesis/inference_folder/data/raw\LoadCase_7931
# Elapsed prediction time:  0.08377194404602051
# LoadCase_7932
# F:/Thesis/inference_folder/data/raw\LoadCase_7932
# Elapsed prediction time:  0.07380390167236328
# LoadCase_7933
# F:/Thesis/inference_folder/data/raw\LoadCase_7933
# Elapsed prediction time:  0.07676362991333008
# LoadCase_7934
# F:/Thesis/inference_folder/data/raw\LoadCase_7934
# Elapsed prediction time:  0.07579851150512695
# LoadCase_7935
# F:/Thesis/inference_folder/data/raw\LoadCase_7935
# Elapsed prediction time:  0.07380342483520508
# LoadCase_7936
# F:/Thesis/inference_folder/data/raw\LoadCase_7936
# Elapsed prediction time:  0.07579731941223145
# LoadCase_7937
# F:/Thesis/inference_folder/data/raw\LoadCase_7937
# Elapsed prediction time:  0.07480072975158691
# LoadCase_7938
# F:/Thesis/inference_folder/data/raw\LoadCase_7938
# Elapsed prediction time:  0.0967409610748291
# LoadCase_7939
# F:/Thesis/inference_folder/data/raw\LoadCase_7939
# Elapsed prediction time:  0.0747990608215332
# LoadCase_7940
# F:/Thesis/inference_folder/data/raw\LoadCase_7940
# Elapsed prediction time:  0.07579755783081055
# LoadCase_7941
# F:/Thesis/inference_folder/data/raw\LoadCase_7941
# Elapsed prediction time:  0.07879042625427246
# LoadCase_7942
# F:/Thesis/inference_folder/data/raw\LoadCase_7942
# Elapsed prediction time:  0.07679462432861328
# LoadCase_7943
# F:/Thesis/inference_folder/data/raw\LoadCase_7943
# Elapsed prediction time:  0.07579779624938965
# LoadCase_7944
# F:/Thesis/inference_folder/data/raw\LoadCase_7944
# Elapsed prediction time:  0.07376551628112793
# LoadCase_7945
# F:/Thesis/inference_folder/data/raw\LoadCase_7945
# Elapsed prediction time:  0.07380366325378418
# LoadCase_7946
# F:/Thesis/inference_folder/data/raw\LoadCase_7946
# Elapsed prediction time:  0.07254767417907715
# LoadCase_7947
# F:/Thesis/inference_folder/data/raw\LoadCase_7947
# Elapsed prediction time:  0.07372188568115234
# LoadCase_7948
# F:/Thesis/inference_folder/data/raw\LoadCase_7948
# Elapsed prediction time:  0.09175586700439453
# LoadCase_7949
# F:/Thesis/inference_folder/data/raw\LoadCase_7949
# Elapsed prediction time:  0.0747990608215332
# LoadCase_7950
# F:/Thesis/inference_folder/data/raw\LoadCase_7950
# Elapsed prediction time:  0.07783126831054688
# LoadCase_7951
# F:/Thesis/inference_folder/data/raw\LoadCase_7951
# Elapsed prediction time:  0.07277274131774902
# LoadCase_7952
# F:/Thesis/inference_folder/data/raw\LoadCase_7952
# Elapsed prediction time:  0.07583093643188477
# LoadCase_7953
# F:/Thesis/inference_folder/data/raw\LoadCase_7953
# Elapsed prediction time:  0.07536673545837402
# LoadCase_7954
# F:/Thesis/inference_folder/data/raw\LoadCase_7954
# Elapsed prediction time:  0.07280445098876953
# LoadCase_7955
# F:/Thesis/inference_folder/data/raw\LoadCase_7955
# Elapsed prediction time:  0.09275221824645996
# LoadCase_7956
# F:/Thesis/inference_folder/data/raw\LoadCase_7956
# Elapsed prediction time:  0.07476377487182617
# LoadCase_7957
# F:/Thesis/inference_folder/data/raw\LoadCase_7957
# Elapsed prediction time:  0.08078193664550781
# LoadCase_7958
# F:/Thesis/inference_folder/data/raw\LoadCase_7958
# Elapsed prediction time:  0.0728461742401123
# LoadCase_7959
# F:/Thesis/inference_folder/data/raw\LoadCase_7959
# Elapsed prediction time:  0.07579684257507324
# LoadCase_7960
# F:/Thesis/inference_folder/data/raw\LoadCase_7960
# Elapsed prediction time:  0.09474658966064453
# LoadCase_7961
# F:/Thesis/inference_folder/data/raw\LoadCase_7961
# Elapsed prediction time:  0.07872891426086426
# LoadCase_7962
# F:/Thesis/inference_folder/data/raw\LoadCase_7962
# Elapsed prediction time:  0.0857701301574707
# LoadCase_7963
# F:/Thesis/inference_folder/data/raw\LoadCase_7963
# Elapsed prediction time:  0.07380247116088867
# LoadCase_7964
# F:/Thesis/inference_folder/data/raw\LoadCase_7964
# Elapsed prediction time:  0.07281041145324707
# LoadCase_7965
# F:/Thesis/inference_folder/data/raw\LoadCase_7965
# Elapsed prediction time:  0.07346582412719727
# LoadCase_7966
# F:/Thesis/inference_folder/data/raw\LoadCase_7966
# Elapsed prediction time:  0.9215760231018066
# LoadCase_7967
# F:/Thesis/inference_folder/data/raw\LoadCase_7967
# Elapsed prediction time:  0.07474517822265625
# LoadCase_7968
# F:/Thesis/inference_folder/data/raw\LoadCase_7968
# Elapsed prediction time:  0.07579803466796875
# LoadCase_7970
# F:/Thesis/inference_folder/data/raw\LoadCase_7970
# Elapsed prediction time:  0.07718157768249512
# LoadCase_7971
# F:/Thesis/inference_folder/data/raw\LoadCase_7971
# Elapsed prediction time:  0.08178186416625977
# LoadCase_7972
# F:/Thesis/inference_folder/data/raw\LoadCase_7972
# Elapsed prediction time:  0.07181000709533691
# LoadCase_7973
# F:/Thesis/inference_folder/data/raw\LoadCase_7973
# Elapsed prediction time:  0.07274937629699707
# LoadCase_7974
# F:/Thesis/inference_folder/data/raw\LoadCase_7974
# Elapsed prediction time:  0.07181096076965332
# LoadCase_7975
# F:/Thesis/inference_folder/data/raw\LoadCase_7975
# Elapsed prediction time:  0.07384490966796875
# LoadCase_7976
# F:/Thesis/inference_folder/data/raw\LoadCase_7976
# Elapsed prediction time:  0.0767369270324707
# LoadCase_7977
# F:/Thesis/inference_folder/data/raw\LoadCase_7977
# Elapsed prediction time:  0.07378625869750977
# LoadCase_7978
# F:/Thesis/inference_folder/data/raw\LoadCase_7978
# Elapsed prediction time:  0.08476829528808594
# LoadCase_7979
# F:/Thesis/inference_folder/data/raw\LoadCase_7979
# Elapsed prediction time:  0.07380247116088867
# LoadCase_7980
# F:/Thesis/inference_folder/data/raw\LoadCase_7980
# Elapsed prediction time:  0.08178162574768066
# LoadCase_7981
# F:/Thesis/inference_folder/data/raw\LoadCase_7981
# Elapsed prediction time:  0.08580851554870605
# LoadCase_7982
# F:/Thesis/inference_folder/data/raw\LoadCase_7982
# Elapsed prediction time:  0.08078408241271973
# LoadCase_7983
# F:/Thesis/inference_folder/data/raw\LoadCase_7983
# Elapsed prediction time:  0.15359091758728027
# LoadCase_7984
# F:/Thesis/inference_folder/data/raw\LoadCase_7984
# Elapsed prediction time:  0.09677577018737793
# LoadCase_7985
# F:/Thesis/inference_folder/data/raw\LoadCase_7985
# Elapsed prediction time:  0.09575533866882324
# LoadCase_7986
# F:/Thesis/inference_folder/data/raw\LoadCase_7986
# Elapsed prediction time:  0.08879709243774414
# LoadCase_7987
# F:/Thesis/inference_folder/data/raw\LoadCase_7987
# Elapsed prediction time:  0.10267925262451172
# LoadCase_7988
# F:/Thesis/inference_folder/data/raw\LoadCase_7988
# Elapsed prediction time:  0.08477234840393066
# LoadCase_7989
# F:/Thesis/inference_folder/data/raw\LoadCase_7989
# Elapsed prediction time:  0.08776998519897461
# LoadCase_7990
# F:/Thesis/inference_folder/data/raw\LoadCase_7990
# Elapsed prediction time:  0.08973193168640137
# LoadCase_7991
# F:/Thesis/inference_folder/data/raw\LoadCase_7991
# Elapsed prediction time:  0.08481001853942871
# LoadCase_7992
# F:/Thesis/inference_folder/data/raw\LoadCase_7992
# Elapsed prediction time:  0.08577108383178711
# LoadCase_7993
# F:/Thesis/inference_folder/data/raw\LoadCase_7993
# Elapsed prediction time:  0.0887289047241211
# LoadCase_7994
# F:/Thesis/inference_folder/data/raw\LoadCase_7994
# Elapsed prediction time:  0.08796310424804688
# LoadCase_7995
# F:/Thesis/inference_folder/data/raw\LoadCase_7995
# Elapsed prediction time:  0.09374880790710449
# LoadCase_7996
# F:/Thesis/inference_folder/data/raw\LoadCase_7996
# Elapsed prediction time:  0.07579874992370605
# LoadCase_7997
# F:/Thesis/inference_folder/data/raw\LoadCase_7997
# Elapsed prediction time:  0.07878947257995605
# LoadCase_7998
# F:/Thesis/inference_folder/data/raw\LoadCase_7998
# Elapsed prediction time:  0.08174681663513184
# LoadCase_7999
# F:/Thesis/inference_folder/data/raw\LoadCase_7999
# Elapsed prediction time:  0.07579541206359863

# %%
t = time.time()
time.sleep(1)
elapsed = time.time() - t
print(elapsed)
# Out:
# 1.000675916671753
